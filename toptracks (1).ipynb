# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f46c6a7d-c005-47db-9d52-ed51155d3a30" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f46c6a7d-c005-47db-9d52-ed51155d3a30">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
af = pd.read_csv("tamilmusic_directors_toptracks.csv")

# %%
new_af = af.copy()

# %%
print("\n1. Random Records")
display(new_af.sample(5))
# Out:
# 1. Random Records
#             artist_name                                         track_name  \
# 36       Harris Jayaraj                                      Ennamo Yeadho
# 3             Ilayaraja  Nila Kayuthu Neram Nalla Neram (From "Sakalaka...
# 68   Santhosh Narayanan                Mainaru Vetti Katti (From "Dasara")
# 15          A.R. Rahman                                       Kun Faya Kun
# 113     Devi Sri Prasad                                         Uppenantha
#
#      popularity  duration_ms                                           album  \
# 36           61       333600         KO (Original Motion Picture Soundtrack)
# 3            47       272760                                   Iravin Sorgam
# 68           28       203052    Mainaru Vetti Katti (From "Dasara") - Single
# 15           71       470500                                        Rockstar
# 113          64       327640  Aarya - 2 (Original Motion Picture Soundtrack)
#
# ...

# %%
print("\n2. First 5 Records")
display(new_af.head())
# Out:
# 2. First 5 Records
#   artist_name                                         track_name  popularity  \
# 0   Ilayaraja  Ooru Sanam Thoongidichu (From "Mella Thirandha...          19
# 1   Ilayaraja                       Oru Naalum (From "Ejjaman" )           2
# 2   Ilayaraja                Aalappol Velappol (From "Ejjaman" )           1
# 3   Ilayaraja  Nila Kayuthu Neram Nalla Neram (From "Sakalaka...          47
# 4   Ilayaraja                Naanaga Naanillai Thaye (Version 1)          48
#
#    duration_ms                                              album  \
# 0       278400                               Ilayaraja Love bites
# 1       359026                               Ilayaraja Love Beats
# 2       304848                               Ilayaraja Love Beats
# 3       272760                                      Iravin Sorgam
# 4       272493  Thoongathe Thambi Thoongathe (Original Motion ...
#
#   release_date collaborating_artist  explicit  number_of_markets  \
# ...
